# %%
Application_id= '0a44920a-ad6a-49f9-b9f2-96d41062bca4',
directory = 'fa926bf9-bb0f-4042-b29d-405c76fc8de6',
secret = 'HhZ8Q~eS~78XGoqMDgyaqNKLpDWMpk3.lmLvAbTz'


container_name = "dbfscontainer",
storage_account_name= "datalakeabd1",
mount_point = "myfiles"

# %%
# defining Mount Configure
configs = {"fs.azure.account.auth.type": "OAuth",
          "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
          "fs.azure.account.oauth2.client.id": "0a44920a-ad6a-49f9-b9f2-96d41062bca4",
          "fs.azure.account.oauth2.client.secret": "HhZ8Q~eS~78XGoqMDgyaqNKLpDWMpk3.lmLvAbTz",
          "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/fa926bf9-bb0f-4042-b29d-405c76fc8de6/oauth2/token"}

# %%
# Mounting the container of Storage accout
dbutils.fs.mount(
  source = "abfss://dbfscontainer@datalakeabd1.dfs.core.windows.net/",
  mount_point = f"/mnt/{mount_point}",
  extra_configs = configs)
