# %%
# %fs
ls /
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Workspace/</td><td>Workspace/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks/</td><td>databricks/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls  dbfs:/Workspace/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Workspace/Repos/</td><td>Repos/</td><td>4096</td><td>1770277124935</td></tr><tr><td>dbfs:/Workspace/Shared/</td><td>Shared/</td><td>4096</td><td>1770277124935</td></tr><tr><td>dbfs:/Workspace/Users/</td><td>Users/</td><td>4096</td><td>1770277124935</td></tr><tr><td>dbfs:/Workspace/adb10am/</td><td>adb10am/</td><td>4096</td><td>1770277124935</td></tr></tbody></table></div>

# %%
# %fs
ls dbfs:/Workspace/adb10am/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls dbfs:/Workspace/adb10am/Working_with_CSV_files
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Workspace/adb10am/Working_with_CSV_files</td><td>Working_with_CSV_files</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.ls('/')
# Out:
# [FileInfo(path='dbfs:/Volumes/', name='Volumes/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/Workspace/', name='Workspace/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks/', name='databricks/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0)]

# %%
# Application_id : 43aae9bf-1d21-4891-89a6-91d1193ec78b
# dir  : 76c548f2-a55a-420e-9763-0ee29423e5a2
# secret : lZE8Q~66MhmM~Q4PbD6wjEwYDn5aC1c8EI2fEad6

# %%
spark.conf.set("fs.azure.account.auth.type.adbstroagelake10.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.adbstroagelake10.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.adbstroagelake10.dfs.core.windows.net", "43aae9bf-1d21-4891-89a6-91d1193ec78b")
spark.conf.set("fs.azure.account.oauth2.client.secret.adbstroagelake10.dfs.core.windows.net","lZE8Q~66MhmM~Q4PbD6wjEwYDn5aC1c8EI2fEad6" )
spark.conf.set("fs.azure.account.oauth2.client.endpoint.adbstroagelake10.dfs.core.windows.net", "https://login.microsoftonline.com/76c548f2-a55a-420e-9763-0ee29423e5a2/oauth2/token")

# %%
dbutils.fs.ls("abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files")
# Out:
# [FileInfo(path='abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files/dept.json', name='dept.json', size=251, modificationTime=1770286526000),
#  FileInfo(path='abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files/emps.json', name='emps.json', size=298, modificationTime=1770286526000),
#  FileInfo(path='abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files/emps2.json', name='emps2.json', size=479, modificationTime=1770286526000),
#  FileInfo(path='abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files/flight-time.json', name='flight-time.json', size=86850442, modificationTime=1770286535000),
#  FileInfo(path='abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files/person.json', name='person.json', size=208, modificationTime=1770286527000),
#  FileInfo(path='abfss://pyspark@adbstroagelake10.dfs.core.windows.net/json-files/players.json', name='players.json', size=274, modificationTime=1770286526000)]

# %%
base_dir="abfss://pyspark@adbstroagelake10.dfs.core.windows.net/"
df=spark.read.json(base_dir+"jsonfiles/emps.json")
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dno</th><th>eid</th><th>ename</th><th>sal</th><th>sex</th></tr></thead><tbody><tr><td>11</td><td>101</td><td>Miller</td><td>10000</td><td>m</td></tr><tr><td>12</td><td>102</td><td>Blake</td><td>20000</td><td>m</td></tr><tr><td>11</td><td>103</td><td>Sony</td><td>30000</td><td>f</td></tr><tr><td>12</td><td>104</td><td>Sonia</td><td>40000</td><td>f</td></tr><tr><td>13</td><td>105</td><td>James</td><td>50000</td><td>m</td></tr></tbody></table></div>
