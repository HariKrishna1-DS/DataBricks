# %%
x=10   
Y=20
print(x+Y)
# Out:
# -10

# %% [markdown]
# Hello world

# %%
# %fs
ls /
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volume/</td><td>Volume/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/volume/</td><td>volume/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/volumes/</td><td>volumes/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs
ls /databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
ls /databricks-datasets/amazon/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/amazon/README.md</td><td>README.md</td><td>396</td><td>1457319771000</td></tr><tr><td>dbfs:/databricks-datasets/amazon/data20K/</td><td>data20K/</td><td>0</td><td>1766037915906</td></tr><tr><td>dbfs:/databricks-datasets/amazon/test4K/</td><td>test4K/</td><td>0</td><td>1766037915906</td></tr><tr><td>dbfs:/databricks-datasets/amazon/users/</td><td>users/</td><td>0</td><td>1766037915906</td></tr></tbody></table></div>

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %oprofile  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %pipeline_codegen  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %restart_python  %rm  %rmdir  %run  %save  %sc  %set_cell_max_output_size_in_mb  %set_env  %store  %sx  %system  %tb  %time  %timeit  %top  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
import pandas as pd
data = (10,"kdshf",34235)
df = pd.DataFrame(data)
df
# Out:
#        0
# 0     10
# 1  kdshf
# 2  34235

# %% [markdown]
# #18-12-2025

# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
# ...

# %%
dbutils.secrets.listScopes()
# Out:
# []

# %% [markdown]
# ### ## Notebook Utilty
# ** Notebook EXit() **

# %%
dbutils.notebook.exit("Hi Hari this is childbook")

# %% [markdown]
# **Notebook- Run() **

# %%
# %fs
ls p`/databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.notebook.run("./sample",20)
# Out:
# 'Hi Hari this is childbook'

# %% [markdown]
# # dbutility.**widgets**

# %%
dbutils.widgets.text("name","hari")

# %%
var = dbutils.widgets.get("name")
print(var)
# Out:
# Hi,your widgets is complete

# %% [markdown]
# # 19-12-2025

# %%
p_msg = dbutils.widgets.get("name")
print(p_msg)
# Out:
# Hi,your widgets is complete

# %%
print("Hi agasthaya this is Harikrishna, Nice to Meet you here"+p_msg)
# Out:
# Hi agasthaya this is Harikrishna, Nice to Meet you hereHi,your widgets is complete

# %% [markdown]
# # DBFS

# %%
# %fs
ls dbfs:/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs 
ls /
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls dbfs:/databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls dbfs:/databricks-datasets/flowers/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/flowers/License.txt</td><td>License.txt</td><td>418049</td><td>1594145601000</td></tr><tr><td>dbfs:/databricks-datasets/flowers/README.md</td><td>README.md</td><td>1406</td><td>1625611058000</td></tr><tr><td>dbfs:/databricks-datasets/flowers/delta/</td><td>delta/</td><td>0</td><td>1766161264606</td></tr></tbody></table></div>
